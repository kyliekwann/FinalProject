# %%
# Initial imports
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://postgres:analyzeup@database-analyzeup.c9mmdejuhxq9.us-west-1.rds.amazonaws.com:5432/analyzeup_project', echo=False)
# Out:
# /Users/hankaizhu/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
query = engine.execute("SELECT * FROM comprehensive_table").fetchall()
query[0:2]
# Out:
# [('6581', 'Society of St. Vincent de Paul of San Mateo County', '50 North B Street ', 'San Mateo', 'CA', '94401', 'San Mateo', 'http://svdpsm.org/', 'Human Services', 'Social Services', 'Providing person to person safety net services of time, talent and resources to help our neighbors in need.', "In the spirit of love and justice, the Society of St. Vincent de Paul of San Mateo County (SVdP) provides person to person services of time, talent a ... (694 characters truncated) ...  SVdP's Catherine Center provides a residential rehabilitation program for women recently released from prison and advocates for systemic change.<br>", '5025196.0', '5343340.0', '330601.0', '16076.0', '7627194.0', '3'),
# ...

# %%
column_names = engine.execute("SELECT * FROM comprehensive_table").keys()
column_names
# Out:
# RMKeyView(['OrgID', 'Charity Name', 'Address ', 'City', 'State', 'Zip', 'County', 'Website URL', 'Category', 'Cause', 'Tag Line', 'Mission', 'Total Revenue', 'Total Expenses', 'Fundraising Expenses', 'CEO Salary', 'Total Net Assets', 'Overall Rating'])

# %%
pd.DataFrame(query, columns=column_names)
# Out:
#       OrgID                                       Charity Name  \
# 0      6581  Society of St. Vincent de Paul of San Mateo Co...
# 1     14575                          Society of the Cincinnati
# 2     15858                           Society of the Four Arts
# 3     18757                                        Soi Dog USA
# 4     14463  Soil Born Farms Urban Agriculture & Education ...
# ...     ...                                                ...
# 8925   4476  Society for the Protection of New Hampshire Fo...
# 8926   7125                Society for Women's Health Research
# 8927   3625           Society of St. Vincent de Paul - Phoenix
# 8928  12188  Society of St. Vincent De Paul Archdiocesan Co...
# 8929   4477   Society of St. Vincent de Paul of Alameda County
#
#                                     Address             City State    Zip  \
# 0                         50 North B Street        San Mateo    CA  94401
# ...
